# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


data={"Days":[1,2,3,4,5],
      "NOP":[50,40,60,30,44]}
df=pd.DataFrame(data)
print(df)

sns.lineplot(data=data, x="Days", y="NOP") 
plt.show()
# Out:
#    Days  NOP
# 0     1   50
# 1     2   40
# 2     3   60
# 3     4   30
# 4     5   44

# %%
data=pd.read_excel("")
print(data)


# sns.iineplot(data=data,x="bussiness unit",y="age")
sns.iineplot(data=data,x="bussiness unit",y="age", style="Gender")

# sns.iineplot(data=data,x="bussiness unit",y="age", hue="Gender", style="Ehnicity")
# sns.iineplot(data=data,x="bussiness unit",y="age", hue="Ehnicity", style="Gender")


# for color:-
color=sns.color_palette("viridis")
sns.iineplot(data=data,x="bussiness unit",y="age", hue="Ehnicity",palette=color) #--> gives  colors
sns.iineplot(data=data,x="bussiness unit",y="age", hue="Ehnicity") #--> gives multiple colors
plt.show()
