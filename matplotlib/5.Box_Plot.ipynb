# %%
import matplotlib.pyplot as plt

# l=[12,13,15,24,25,78,98,56,24,26,56,34,95,126,24,54,78]
l=[12,13,15,24,25,78,98,56,24,26,56,34,95,126,24,54]


plt.boxplot(l)
plt.show()

# %%
import matplotlib.pyplot as plt

l=[12,13,15,24,25,78,98,56,24]
l1=[12,13,15,24,25,78,98,56,24,26,56,34,95,126,24,54]

plot_values=[l,l1]
plt.boxplot(plot_values)
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt

data=pd.read_excel("")
df=pd.DataFrame(data) 

plt.boxplot(df["amount/annual salary"])
plt.show()
