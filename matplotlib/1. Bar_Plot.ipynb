# %%
#without pandas


import matplotlib.pyplot as plt

y= [98,67,88,95,88]
x=["Part1","Part2","Part3","Part4","Part5"]
colors=["red","blue","yellow","pink","orange",]
# plt.bar(x,y,color=colors)
plt.bar(x,y,color=colors, edgecolor="black")

# plt.bar(x,y , color="red")
plt.xlabel("x axis" , fontsize=17)
plt.ylabel("y axis" , fontsize=17)
plt.title("heading",fontsize=20)
plt.show()

# %%
#with pandas

import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_excel("file link")

df=pd.DataFrame(data)


# plt.bar(df["payement mode"],df["amount"]) # graph between payment mode and amount is made


print(df)
grouped_by= df.groupby("payment mode")["amount"].sum
print(grouped_by)
plt.bar(grouped_by.index,grouped_by.values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 6
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 6 data=pd.read_excel("file link")
#       7 df=pd.DataFrame(data)
#       8 plt.bar(df["payement mode"],df["amount"])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...
