# %%
import matplotlib.pyplot as plt

a= [20,30,40,50,0,50,40,30,20,40,60,40,20]

# plt.violinplot(a)

plt.violinplot(a, showmedians = True)
plt.show()

# %%
import pandas as pd

data =pd.read_excel("")
df=pd.DataFrame(data)
print(df)

plt.violinplot(df["äge"]) , showmedians=True
plt.show()
