# %%
import matplotlib.pyplot as plt
x=["day1","day2","day3","day4","day5"]
y=[30,40,25,30,40]

plt.step(x,y,where="post",marker="o")

# %%
import pandas as pd

data =pd.read_excel("")
df=pd.DataFrame(data)
# print(df)   
group=df.groupby("category").agg({"amount": "sum"})
plt.(group)
plt.step(group.index["amount"],where="post",marker="o")
plt.show()
